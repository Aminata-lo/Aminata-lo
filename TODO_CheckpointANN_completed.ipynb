# %% [markdown]
# <a href="https://colab.research.google.com/github/Aminata-lo/Aminata-lo/blob/main/TODO_CheckpointANN_completed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
# In this practical, we implement and train a feed-forward neural network (also known as an "MLP" for "multi-layer perceptron") on a dataset called "Fashion MNIST", consisting of small greyscale images of items of fashion.

# %% [markdown]
# # Learning Objectives
#
# * Understand how to use Keras Layers to build a neural network architecture
# * Understand how a model is trained and evaluated
# * Understand the concept of train/validation/test split and why it's useful

# %%
from __future__ import print_function

import keras
from keras.datasets import fashion_mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
#from keras.optimizers import RMSprop
import numpy as np 
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.optimizers import RMSprop
from keras.utils import np_utils

# %% [markdown]
# # Data
# In this practical, we use the Fashion MNIST dataset consisting of 70,000 greyscale images and their labels. The dataset is divided
#  into 60,000 training images and 10,000 test images. The idea is to train a **classifier** to identify the class value (what type of fashion item it is) given the image. We train and *tune* a model on the 60,000 training images and then evaluate how well it classifies the 10,000 test images that the model did not see during training. This task is an example of a **supervised learning** problem, where we are given both input and labels (targets) to learn from. This is in contrast to **unsupervised learning** where we only have inputs from which to learn patterns or **reinforcement learning** where an agent learns how to maximise a reward signal through interaction with its environment.

# %% [markdown]
# ![Texte alternatif…](https://res.cloudinary.com/practicaldev/image/fetch/s---fNWEeWA--/c_imagga_scale,f_auto,fl_progressive,h_420,q_auto,w_1000/https://raw.githubusercontent.com/zalandoresearch/fashion-mnist/master/doc/img/fashion-mnist-sprite.png)

# %% [markdown]
# # Train/Validation/Test Split
#
# When we build machine learning models, the goal is to build a model that will perform well on future data that we have not seen yet. We say that we want our models to be able to generalise well from whatever training data we can collect and do have available, to whatever data we will be applying them to in future. To do this, we split whatever data we have available into a training set, a validation set and a test set. The idea is that we train our model and use the performance on the validation set to make any adjustments to the model and its hyperparameters, but then we report the final accuracy on the test set. The test set (which we never train on), therefore acts as a proxy for our future data.

# %%
(train_and_validation_images, train_and_validation_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
# Construct a validation set from the last 10000 images and labels from 
# train_and_validation_images and train_and_validation_labels
validation_images = train_and_validation_images[-10000:, :, :]

validation_labels = train_and_validation_labels[-10000:]

# Construct a training set from the first 50000 images and labels.
train_images = train_and_validation_images[:50000, :, :]

train_labels = train_and_validation_labels[:50000]

# %%
type(validation_labels)
# Out:
# numpy.ndarray

# %%
text_labels = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
plt.figure()
random_index = np.random.randint(0, len(train_images))
plt.imshow(train_images[random_index], cmap='gray')
plt.colorbar()
numerical_label = train_labels[random_index]
text_description = text_labels[numerical_label]
plt.title('True Class: {} ("{}")'.format(numerical_label, text_description))

plt.gca().grid(False)

# %%
# Another view, showing 50 randomly selected images at a time
plt.figure(figsize=(20,20))
for i in range(50):
    plt.subplot(5,10,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid('off')
    
    img_index = np.random.randint(0, 50000)
    plt.imshow(train_images[img_index], cmap=plt.cm.gray)
    plt.xlabel(text_labels[train_labels[img_index]])

# %% [markdown]
# # Preprocess

# %%
# Flatten

train_images_flatten = train_images.reshape(train_images.shape[0], 784)
validation_images_flatten = validation_images.reshape(validation_images.shape[0], 784)
test_images_flatten = test_images.reshape(test_images.shape[0], 784)

# %%
# Normalize
train_images_model = train_images_flatten/255
validation_images_model = validation_images_flatten/255
test_images_model = test_images_flatten/255

# %%
# convert class vectors to binary class matrices
train_labels_categ = keras.utils.np_utils.to_categorical(train_labels, 10)
validation_labels_categ = keras.utils.np_utils.to_categorical(validation_labels, 10)
test_labels_categ = keras.utils.np_utils.to_categorical(test_labels, 10)

# %% [markdown]
# # Train

# %%
batch_size = 128
num_classes = 10
epochs = 40

# Create a sequential model here 

model= Sequential([
   Dense(256, input_dim = 784, activation='relu'),     
   Dense(128, activation='softmax'),    
   Dense(10, activation='softmax')])



# End Code

# %%
 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               200960
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 235,146
# Trainable params: 235,146
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(train_images_model, train_labels_categ,
                    batch_size=128,
                    epochs=40,
                    verbose=1,
                    validation_data=(validation_images_model, validation_labels_categ))
# Out:
# Epoch 1/40
# 391/391 [==============================] - 5s 10ms/step - loss: 1.9126 - accuracy: 0.5370 - val_loss: 1.7101 - val_accuracy: 0.5514
# Epoch 2/40
# 391/391 [==============================] - 3s 9ms/step - loss: 1.5084 - accuracy: 0.5707 - val_loss: 1.3503 - val_accuracy: 0.5636
# Epoch 3/40
# 391/391 [==============================] - 3s 8ms/step - loss: 1.2209 - accuracy: 0.5747 - val_loss: 1.1229 - val_accuracy: 0.5755
# Epoch 4/40
# 391/391 [==============================] - 3s 8ms/step - loss: 1.0379 - accuracy: 0.5797 - val_loss: 1.0158 - val_accuracy: 0.5702
# Epoch 5/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.9289 - accuracy: 0.5879 - val_loss: 0.9253 - val_accuracy: 0.5681
# Epoch 6/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.8607 - accuracy: 0.5979 - val_loss: 0.8533 - val_accuracy: 0.5937
# Epoch 7/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.8181 - accuracy: 0.6144 - val_loss: 0.8207 - val_accuracy: 0.6281
# Epoch 8/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.7792 - accuracy: 0.6594 - val_loss: 0.8193 - val_accuracy: 0.6345
# Epoch 9/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.7344 - accuracy: 0.7028 - val_loss: 0.7543 - val_accuracy: 0.6999
# Epoch 10/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.6895 - accuracy: 0.7383 - val_loss: 0.7093 - val_accuracy: 0.7188
# Epoch 11/40
# 391/391 [==============================] - 3s 9ms/step - loss: 0.6533 - accuracy: 0.7685 - val_loss: 0.6760 - val_accuracy: 0.7841
# Epoch 12/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.6138 - accuracy: 0.8079 - val_loss: 0.6511 - val_accuracy: 0.7987
# Epoch 13/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.5744 - accuracy: 0.8214 - val_loss: 0.6032 - val_accuracy: 0.8137
# Epoch 14/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.5360 - accuracy: 0.8320 - val_loss: 0.5938 - val_accuracy: 0.8129
# Epoch 15/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.5070 - accuracy: 0.8409 - val_loss: 0.5521 - val_accuracy: 0.8266
# Epoch 16/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.4804 - accuracy: 0.8469 - val_loss: 0.5384 - val_accuracy: 0.8290
# Epoch 17/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.4550 - accuracy: 0.8630 - val_loss: 0.5038 - val_accuracy: 0.8608
# Epoch 18/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.4253 - accuracy: 0.8817 - val_loss: 0.4989 - val_accuracy: 0.8591
# Epoch 19/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.4004 - accuracy: 0.8896 - val_loss: 0.4724 - val_accuracy: 0.8616
# Epoch 20/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.3788 - accuracy: 0.8977 - val_loss: 0.4537 - val_accuracy: 0.8683
# Epoch 21/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.3603 - accuracy: 0.9002 - val_loss: 0.4499 - val_accuracy: 0.8744
# Epoch 22/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.3444 - accuracy: 0.9045 - val_loss: 0.4474 - val_accuracy: 0.8726
# Epoch 23/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.3309 - accuracy: 0.9076 - val_loss: 0.4321 - val_accuracy: 0.8743
# Epoch 24/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.3196 - accuracy: 0.9091 - val_loss: 0.4335 - val_accuracy: 0.8769
# Epoch 25/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.3093 - accuracy: 0.9114 - val_loss: 0.4270 - val_accuracy: 0.8801
# Epoch 26/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.2987 - accuracy: 0.9146 - val_loss: 0.4206 - val_accuracy: 0.8820
# Epoch 27/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.2881 - accuracy: 0.9160 - val_loss: 0.4207 - val_accuracy: 0.8787
# Epoch 28/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.2811 - accuracy: 0.9175 - val_loss: 0.4429 - val_accuracy: 0.8670
# Epoch 29/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.2746 - accuracy: 0.9201 - val_loss: 0.4245 - val_accuracy: 0.8791
# Epoch 30/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.2679 - accuracy: 0.9215 - val_loss: 0.4124 - val_accuracy: 0.8806
# Epoch 31/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.2631 - accuracy: 0.9219 - val_loss: 0.4148 - val_accuracy: 0.8799
# Epoch 32/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.2545 - accuracy: 0.9250 - val_loss: 0.4183 - val_accuracy: 0.8806
# Epoch 33/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.2493 - accuracy: 0.9265 - val_loss: 0.4230 - val_accuracy: 0.8792
# Epoch 34/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.2458 - accuracy: 0.9274 - val_loss: 0.4362 - val_accuracy: 0.8742
# Epoch 35/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.2412 - accuracy: 0.9272 - val_loss: 0.4226 - val_accuracy: 0.8779
# Epoch 36/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.2324 - accuracy: 0.9309 - val_loss: 0.4190 - val_accuracy: 0.8807
# Epoch 37/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.2310 - accuracy: 0.9313 - val_loss: 0.4127 - val_accuracy: 0.8806
# Epoch 38/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.2274 - accuracy: 0.9322 - val_loss: 0.4245 - val_accuracy: 0.8829
# Epoch 39/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.2219 - accuracy: 0.9330 - val_loss: 0.4246 - val_accuracy: 0.8786
# Epoch 40/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.2164 - accuracy: 0.9348 - val_loss: 0.4256 - val_accuracy: 0.8833

# %% [markdown]
# # Test

# %%
score = model.evaluate(test_images_model, test_labels_categ, verbose=1)
print('Test accuracy:', score[1])
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4542 - accuracy: 0.8710
# Test accuracy: 0.8709999918937683

# %%
test_logits = model.predict(test_images_flatten)

# %%
test_logits
# Out:
# array([[1.36161188e-05, 7.25235427e-09, 2.49480354e-06, ...,
#         8.21913826e-09, 9.90750253e-01, 9.22275428e-03],
#        [9.13107851e-06, 5.64820324e-09, 9.04893816e-01, ...,
#         1.08505716e-07, 3.49511647e-05, 7.38638946e-08],
#        [3.25924780e-08, 9.75037813e-01, 4.41889085e-07, ...,
#         2.25064127e-08, 3.13263399e-06, 7.19079694e-08],
#        ...,
#        [1.36161188e-05, 7.25235427e-09, 2.49480354e-06, ...,
#         8.21913826e-09, 9.90750253e-01, 9.22275428e-03],
#        [3.25924780e-08, 9.75037813e-01, 4.41889085e-07, ...,
#         2.25064127e-08, 3.13263399e-06, 7.19079694e-08],
#        [1.62415963e-05, 5.41006614e-07, 4.33653913e-05, ...,
#         2.58768734e-04, 2.60293982e-05, 9.41047620e-05]], dtype=float32)

# %%
test_predictions = np.argmax(test_logits, axis=1)

# %%
test_predictions
# Out:
# array([8, 2, 1, ..., 8, 1, 5])

# %%
plt.figure(figsize=(18,15))
for i in range(10001):
   plt.subplot(5,6,i+1)
   plt.xticks([])
   plt.yticks([])
   plt.grid('off')
    
   img_index = np.random.randint(0, 10000)
   plt.imshow(test_images[img_index], cmap=plt.cm.gray)
    
   actual_label = int(test_labels[img_index])
   predicted_label = int(test_predictions[img_index])
    
   plt.xlabel("Actual: {} ({})\n Predicted: {} ({})".format(
        actual_label, text_labels[actual_label], predicted_label, text_labels[predicted_label]
    ))
    
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-adfdf0cfe9dc> in <module>()
#       1 plt.figure(figsize=(18,15))
#       2 for i in range(10001):
# ----> 3    plt.subplot(5,6,i+1)
#       4    plt.xticks([])
#       5    plt.yticks([])
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1028
#    1029     fig = gcf()
# -> 1030     a = fig.add_subplot(*args, **kwargs)
#    1031     bbox = a.bbox
#    1032     byebye = []
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1417                     self._axstack.remove(ax)
#    1418
# -> 1419             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1420
#    1421         return self._add_axes_internal(key, a)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      64                 if num < 1 or num > rows*cols:
#      65                     raise ValueError(
# ---> 66                         f"num must be 1 <= num <= {rows*cols}, not {num}")
#      67                 self._subplotspec = GridSpec(
#      68                         rows, cols, figure=self.figure)[int(num) - 1]
#
# ValueError: num must be 1 <= num <= 30, not 31

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
